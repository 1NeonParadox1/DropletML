# %% [markdown]
# # Notebook 04: Random Forest Regression
#
# ## Objective
#
# In this notebook we will:
#
# - Load the processed dataset
# - Train a Random Forest Regressor
# - Evaluate its performance
# - Compare it with the Linear Regression baseline
# - Save the trained model

# %%
print("hello")
# Out:
# hello

# %%
import warnings
warnings.filterwarnings("ignore")

import joblib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

plt.style.use("ggplot")

# %%
X_train = pd.read_csv("../data/processed/X_train.csv")
X_test = pd.read_csv("../data/processed/X_test.csv")

y_train = pd.read_csv("../data/processed/y_train.csv")
y_test = pd.read_csv("../data/processed/y_test.csv")

print(X_train.shape)
print(X_test.shape)
# Out:
# (1198, 9)
# (300, 9)

# %%
rf = RandomForestRegressor(

    n_estimators=100,
    random_state=42,

    n_jobs=-1

)

rf
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
rf.fit(
    X_train,
    y_train.values.ravel()
)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=42)

# %%
predictions = rf.predict(X_test)

# %%
mae = mean_absolute_error(
    y_test,
    predictions
)

rmse = np.sqrt(
    mean_squared_error(
        y_test,
        predictions
    )
)

r2 = r2_score(
    y_test,
    predictions
)

print(f"MAE  : {mae:.4f}")
print(f"RMSE : {rmse:.4f}")
print(f"R²   : {r2:.4f}")
# Out:
# MAE  : 0.0166
# RMSE : 0.0282
# R²   : 0.9953

# %%
plt.figure(figsize=(8,8))

plt.scatter(
    y_test,
    predictions,
    alpha=0.7
)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    color="red"
)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Random Forest: Actual vs Predicted")

plt.show()

# %%
feature_importance = pd.DataFrame({

    "Feature": X_train.columns,

    "Importance": rf.feature_importances_

})

feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

feature_importance
# Out:
#                                             Feature  Importance
# 7                                   Reynolds number    0.619400
# 1                             Impact velocity [m/s]    0.279886
# 8                                      Weber number    0.088997
# 0                              Droplet diameter [m]    0.003110
# 3                             Surface Tension [N/m]    0.002961
# 4                          Dynamic Viscosity [Pa s]    0.002162
# 2                                   Density [kg/m3]    0.001554
# 6              Average depth of micro-channels [µm]    0.001140
# 5  Distance between adjacent laser beam passes [µm]    0.000790

# %%
plt.figure(figsize=(10,6))

plt.barh(
    feature_importance["Feature"],
    feature_importance["Importance"]
)

plt.gca().invert_yaxis()

plt.title("Random Forest Feature Importance")

plt.show()

# %%
joblib.dump(
    rf,
    "../models/random_forest.pkl"
)

print("Random Forest Model Saved!")
# Out:
# Random Forest Model Saved!

# %%
comparison = pd.DataFrame({

    "Model":[

        "Linear Regression",

        "Random Forest"

    ],

    "R²":[

        0.9552,

        r2

    ]

})

comparison
# Out:
#                Model        R²
# 0  Linear Regression  0.955200
# 1      Random Forest  0.995338

# %%
# Training Score
train_r2 = rf.score(
    X_train,
    y_train.values.ravel()
)

# Testing Score
test_r2 = rf.score(
    X_test,
    y_test.values.ravel()
)

print("="*40)
print("Random Forest Performance")
print("="*40)

print(f"Training R² : {train_r2:.6f}")
print(f"Testing R²  : {test_r2:.6f}")
# Out:
# ========================================
# Random Forest Performance
# ========================================
# Training R² : 0.999213
# Testing R²  : 0.995338
