# %% [markdown]
# # Notebook 03: Baseline Machine Learning Model
#
# ## Objective
#
# In this notebook we build our first machine learning model.
#
# We will:
#
# - Load the processed training and testing datasets
# - Standardize the features using `StandardScaler`
# - Train a Linear Regression model
# - Predict the spreading coefficient
# - Evaluate the model using regression metrics
# - Visualize the model performance
# - Save the trained model for future use
#
# ---
# ### Why Linear Regression?
#
# Linear Regression is chosen as our baseline model because it is simple, interpretable, and provides a benchmark against which more advanced models such as Random Forest and XGBoost can be compared.

# %%
import warnings
warnings.filterwarnings("ignore")

import joblib
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

plt.style.use("ggplot")

# %%
X_train = pd.read_csv("../data/processed/X_train.csv")
X_test = pd.read_csv("../data/processed/X_test.csv")

y_train = pd.read_csv("../data/processed/y_train.csv")
y_test = pd.read_csv("../data/processed/y_test.csv")

print("="*50)
print("Training Data Shape")
print("="*50)
print(X_train.shape)

print()

print("="*50)
print("Testing Data Shape")
print("="*50)
print(X_test.shape)
# Out:
# ...
# Training Data Shape
# ...
# (1198, 9)
#
# ...
# Testing Data Shape
# ...
# (300, 9)

# %%
pipeline = Pipeline(

    [

        ("scaler", StandardScaler()),

        ("model", LinearRegression())

    ]

)

pipeline
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', LinearRegression())])

# %%
pipeline.fit(
    X_train,
    y_train
)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('model', LinearRegression())])

# %%
predictions = pipeline.predict(X_test)

# %%
mae = mean_absolute_error(
    y_test,
    predictions
)

rmse = np.sqrt(
    mean_squared_error(
        y_test,
        predictions
    )
)

r2 = r2_score(
    y_test,
    predictions
)

print(f"Mean Absolute Error : {mae:.4f}")
print(f"Root Mean Squared Error : {rmse:.4f}")
print(f"R² Score : {r2:.4f}")
# Out:
# Mean Absolute Error : 0.0682
# Root Mean Squared Error : 0.0873
# R² Score : 0.9552

# %%
plt.figure(figsize=(8,8))

plt.scatter(
    y_test,
    predictions,
    alpha=0.7
)

plt.plot(
    [y_test.min(), y_test.max()],
    [y_test.min(), y_test.max()],
    color="red",
    linewidth=2
)

plt.xlabel("Actual Spreading Coefficient")
plt.ylabel("Predicted Spreading Coefficient")
plt.title("Actual vs Predicted Values")

plt.show()

# %%
residuals = y_test.values.flatten() - predictions.flatten()

plt.figure(figsize=(8,5))

plt.scatter(
    predictions,
    residuals,
    alpha=0.7
)

plt.axhline(
    0,
    color="red",
    linestyle="--"
)

plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")

plt.show()

# %%
joblib.dump(
    pipeline,
    "../models/linear_regression.pkl"
)

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
summary = pd.DataFrame({

    "Metric": [

        "Mean Absolute Error",

        "Root Mean Squared Error",

        "R² Score"

    ],

    "Value": [

        mae,

        rmse,

        r2

    ]

})

summary
# Out:
#                     Metric     Value
# 0      Mean Absolute Error  0.068217
# 1  Root Mean Squared Error  0.087335
# 2                 R² Score  0.955202

# %%
print("="*60)
print("Baseline Linear Regression Model Completed")
print("="*60)

print(f"Training Samples : {len(X_train)}")
print(f"Testing Samples  : {len(X_test)}")
print(f"Features Used    : {X_train.shape[1]}")
print(f"Target Variable  : Spreading Coefficient")
print(f"R² Score         : {r2:.4f}")
# Out:
# ...
# Baseline Linear Regression Model Completed
# ...
# Training Samples : 1198
# Testing Samples  : 300
# Features Used    : 9
# Target Variable  : Spreading Coefficient
# R² Score         : 0.9552

# %%
# Extract the trained Linear Regression model to see which inputs is influencing 
linear_model = pipeline.named_steps["model"]

coefficients = pd.DataFrame({
    "Feature": X_train.columns,
    "Coefficient": linear_model.coef_.flatten()
})

coefficients["Absolute Coefficient"] = coefficients["Coefficient"].abs()

coefficients = coefficients.sort_values(
    by="Absolute Coefficient",
    ascending=False
)

coefficients
# Out:
#                                             Feature  Coefficient  \
# 7                                   Reynolds number     0.338518
# 1                             Impact velocity [m/s]     0.286088
# 3                             Surface Tension [N/m]    -0.277138
# 2                                   Density [kg/m3]    -0.169443
# 4                          Dynamic Viscosity [Pa s]    -0.145080
# 0                              Droplet diameter [m]    -0.086443
# 8                                      Weber number    -0.037099
# 5  Distance between adjacent laser beam passes [µm]     0.014089
# 6              Average depth of micro-channels [µm]    -0.004013
#
#    Absolute Coefficient
# 7              0.338518
# 1              0.286088
# 3              0.277138
# 2              0.169443
# 4              0.145080
# 0              0.086443
# 8              0.037099
# 5              0.014089
# 6              0.004013

# %%
plt.figure(figsize=(10,6))

plt.barh(
    coefficients["Feature"],
    coefficients["Coefficient"]
)

plt.xlabel("Coefficient Value")
plt.title("Linear Regression Feature Coefficients")

plt.gca().invert_yaxis()

plt.show()
